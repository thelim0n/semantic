# %%
import requests

API_URL = "http://127.0.0.1:8000/generate"

def ask(question: str):

    response = requests.post(
        API_URL,
        json={"message": question}
    )

    data = response.json()
    print(f"\nВопрос: {question}")
    print(f"Ответ: {data.get('answer')}")


if __name__ == "__main__":
    questions = [
        "Сделай контент-план на 7 дней для фитнес тренера в CSV",
        "Что ты можешь посоветовать, чтобы раскрутить свой телеграм канал?",
        "Какие тренды в маркетинге сейчас?",
        "Какая сегодня погода?",
        "Привет, как дела?"
    ]

    for q in questions:
        ask(q)
# Out:
# Вопрос: Сделай контент-план на 7 дней для фитнес тренера в CSV
# Ответ: Файл content_plan.csv создан.
#
# Если хотите просмотреть содержимое:
#
# День;Тема;Тип_поста;Описание
# Понедельник;Мотивация;Пост;Новый день - новые возможности! Разбудите свой организм и начните тренироваться
# Вторник;Тренировка;Видео;Упражнения для сильных ног
# Среда;Здоровье;Статья;Польза воды для организма
# Четверг;Мотивация;История;Моя история: как я стал фитнес-тренером
# Пятница;Тренировка;Фото;Новая тренировка на выходные!
# Суббота;Здоровье;Совет;Как правильно питаться во время тренировок
# Воскресенье;Мотивация;Цитата;Цитата дня: Здоровье - это сила!
#
# Вопрос: Что ты можешь посоветовать, чтобы раскрутить свой телеграм канал?
# Ответ: Чтобы раскрутить свой Telegram канал, можно использовать несколько стратегий:
#
# 1. **Качественный контент**: Создавайте интересный, информативный и регулярный контент, который будет привлекать и удерживать внимание вашей аудитории.
# 2. **Реклама**: Используйте рекламу в других Telegram каналах или в социальных сетях, чтобы привлечь новых подписчиков.
# 3. **Взаимодействие с аудиторией**: Отвечайте на комментарии и сообщения, проводите опросы и конкурсы, чтобы увеличить вовлеченность аудитории.
# 4. **Сотрудничество с другими каналами**: Сотрудничайте с другими Telegram каналами или инфлюенсерами, чтобы привлечь новую аудиторию.
# 5. **Оптимизация канала**: Оптимизируйте свой канал для поисковых систем, используя relevant keywords в названии и описании канала.
# 6. **Регулярные обновления**: Регулярно обновляйте контент и информацию в канале, чтобы поддерживать интерес аудитории.
# 7. **Анализ и улучшение**: Анализируйте статистику канала и улучшайте стратегию, исходя из результатов.
#
# Также, можно использовать следующие инструменты:
#
# * **Таргетированная реклама**: Используйте таргетированную рекламу в Telegram, чтобы привлечь целевую аудиторию.
# * **Инфлюенсер-маркетинг**: Сотрудничайте с инфлюенсерами, которые имеют большую аудиторию в Telegram.
#
# Но, к сожалению, у меня нет инструментов для непосредственного продвижения вашего канала. Могу только дать советы.
#
# Вопрос: Какие тренды в маркетинге сейчас?
# Ответ: Тренды в маркетинге включают в себя такие направления, как:
#
# *   Развитие цифрового маркетинга и его влияние на бизнес
# *   Использование данных и аналитики для принятия решений
# *   Рост значимости бренд-маркетинга и его роль в продвижении
# *   Развитие контент-маркетинга и его эффективность
# *   Использование ивент-маркетинга для продвижения бренда
# *   Развитие маркетинговых исследований и их роль в принятии решений
#
# Эти тренды помогут businesses оставаться на шаг впереди и эффективно продвигать свой бренд.
#
# Вопрос: Какая сегодня погода?
# Ответ: Я работаю только с маркетингом
#
# Вопрос: Привет, как дела?
# Ответ: Привет! У меня всё отлично, готов помочь с твоими маркетинговыми задачами! Что нужно?
