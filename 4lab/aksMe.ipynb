# %%
import requests

API_URL = "http://127.0.0.1:8000/generate"

def ask(question: str):

    response = requests.post(
        API_URL,
        json={"message": question}
    )

    data = response.json()
    print(f"\nВопрос: {question}")
    print(f"Ответ: {data}")


if __name__ == "__main__":
    questions = [
        "Какие тренды сейчас популярны в TikTok маркетинге?",
        "Сделай контент-план на 7 дней для фитнес-тренера в CSV"
    ]

    for q in questions:
        ask(q)
# Out:
# Вопрос: Какие тренды сейчас популярны в TikTok маркетинге?
# Ответ: {'success': True, 'answer': 'На данный момент популярными трендами в TikTok-маркетинге являются: Использование коротких видеороликов для продвижения товаров и услуг, Создание контента, который вызывает эмоции и стимулирует взаимодействие с аудиторией, Использование хештегов и геотегов для увеличения видимости контента, Работа с инфлюенсерами и блогерами для продвижения бренда, Использование AI-технологий для анализа аудитории и оптимизации контента, Создание контента, который является уникальным и не повторяет уже существующий контент, Использование TikTok для продвижения бренда и увеличения продаж.', 'csv_path': None, 'skill_used': None, 'used_tools': []}
#
# Вопрос: Сделай контент-план на 7 дней для фитнес-тренера в CSV
# Ответ: {'success': True, 'answer': None, 'csv_path': 'data/fitness_trainer_content_plan.csv', 'skill_used': None, 'used_tools': []}
